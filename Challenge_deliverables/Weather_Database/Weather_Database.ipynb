# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 772

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dscrpt = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_dscrpt})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | jalpan
# Processing Record 4 of Set 1 | pisco
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | qaqortoq
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | codrington
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | yazman
# Processing Record 12 of Set 1 | vanino
# Processing Record 13 of Set 1 | pevek
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | liuli
# Processing Record 16 of Set 1 | naryan-mar
# Processing Record 17 of Set 1 | kandrian
# Processing Record 18 of Set 1 | samfya
# Processing Record 19 of Set 1 | haines junction
# Processing Record 20 of Set 1 | tazmalt
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | daru
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | macae
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | fairbanks
# Processing Record 30 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 31 of Set 1 | brae
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 1 | pangnirtung
# Processing Record 36 of Set 1 | keansburg
# Processing Record 37 of Set 1 | atikokan
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | guerrero negro
# Processing Record 40 of Set 1 | sakakah
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | wasilla
# Processing Record 43 of Set 1 | trincomalee
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | grafton
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | yellowknife
# Processing Record 49 of Set 1 | ca mau
# Processing Record 50 of Set 1 | keflavik
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | coos bay
# Processing Record 3 of Set 2 | bull savanna
# Processing Record 4 of Set 2 | kondratovo
# Processing Record 5 of Set 2 | meulaboh
# Processing Record 6 of Set 2 | sao filipe
# Processing Record 7 of Set 2 | voyvozh
# Processing Record 8 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 2 | caravelas
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | praia da vitoria
# Processing Record 14 of Set 2 | altay
# Processing Record 15 of Set 2 | kushiro
# Processing Record 16 of Set 2 | poum
# Processing Record 17 of Set 2 | clyde river
# Processing Record 18 of Set 2 | gao
# Processing Record 19 of Set 2 | tiksi
# Processing Record 20 of Set 2 | georgetown
# Processing Record 21 of Set 2 | coihaique
# Processing Record 22 of Set 2 | ahuimanu
# Processing Record 23 of Set 2 | luderitz
# Processing Record 24 of Set 2 | landskrona
# Processing Record 25 of Set 2 | kalmunai
# Processing Record 26 of Set 2 | olinda
# Processing Record 27 of Set 2 | dalbandin
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | baraboo
# Processing Record 31 of Set 2 | cap-aux-meules
# Processing Record 32 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 2 | taoudenni
# Processing Record 35 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 2 | qaanaaq
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | valverde del camino
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | serov
# Processing Record 41 of Set 2 | alofi
# Processing Record 42 of Set 2 | sorland
# Processing Record 43 of Set 2 | nanakuli
# Processing Record 44 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 2 | kathmandu
# Processing Record 46 of Set 2 | dicabisagan
# Processing Record 47 of Set 2 | liverpool
# Processing Record 48 of Set 2 | moron
# Processing Record 49 of Set 2 | vestmannaeyjar
# Processing Record 50 of Set 2 | broome
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | geraldton
# Processing Record 3 of Set 3 | igrim
# Processing Record 4 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 5 of Set 3 | guaraniacu
# Processing Record 6 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 7 of Set 3 | hobart
# Processing Record 8 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | canton
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | bamako
# Processing Record 13 of Set 3 | port lincoln
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | cape town
# Processing Record 16 of Set 3 | chapais
# Processing Record 17 of Set 3 | tarabha
# Processing Record 18 of Set 3 | wokha
# Processing Record 19 of Set 3 | gombong
# Processing Record 20 of Set 3 | saint-augustin
# Processing Record 21 of Set 3 | aviles
# Processing Record 22 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | ponca city
# Processing Record 25 of Set 3 | saldanha
# Processing Record 26 of Set 3 | parnu-jaagupi
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | ust-tsilma
# Processing Record 29 of Set 3 | henties bay
# Processing Record 30 of Set 3 | boralday
# Processing Record 31 of Set 3 | kemijarvi
# Processing Record 32 of Set 3 | kloulklubed
# Processing Record 33 of Set 3 | shar
# Processing Record 34 of Set 3 | iquitos
# Processing Record 35 of Set 3 | broken hill
# Processing Record 36 of Set 3 | asuncion nochixtlan
# Processing Record 37 of Set 3 | krasnousolskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | mount isa
# Processing Record 40 of Set 3 | knysna
# Processing Record 41 of Set 3 | buala
# Processing Record 42 of Set 3 | bowen
# Processing Record 43 of Set 3 | la tuque
# Processing Record 44 of Set 3 | tautira
# Processing Record 45 of Set 3 | pringsewu
# Processing Record 46 of Set 3 | okara
# Processing Record 47 of Set 3 | berlevag
# Processing Record 48 of Set 3 | jalu
# Processing Record 49 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 3 | cherskiy
# Processing Record 1 of Set 4 | esperance
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | port macquarie
# Processing Record 4 of Set 4 | hofn
# Processing Record 5 of Set 4 | deputatskiy
# Processing Record 6 of Set 4 | albany
# Processing Record 7 of Set 4 | amga
# Processing Record 8 of Set 4 | ponta do sol
# Processing Record 9 of Set 4 | port-gentil
# Processing Record 10 of Set 4 | payson
# Processing Record 11 of Set 4 | archidona
# Processing Record 12 of Set 4 | domoni
# Processing Record 13 of Set 4 | kasongo-lunda
# Processing Record 14 of Set 4 | birao
# Processing Record 15 of Set 4 | sao francisco do sul
# Processing Record 16 of Set 4 | klaksvik
# Processing Record 17 of Set 4 | vitim
# Processing Record 18 of Set 4 | dunedin
# Processing Record 19 of Set 4 | krasnyy yar
# Processing Record 20 of Set 4 | sao joao da barra
# Processing Record 21 of Set 4 | codajas
# Processing Record 22 of Set 4 | kudahuvadhoo
# Processing Record 23 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 4 | bilma
# Processing Record 25 of Set 4 | camacha
# Processing Record 26 of Set 4 | namatanai
# Processing Record 27 of Set 4 | rongcheng
# Processing Record 28 of Set 4 | lodja
# Processing Record 29 of Set 4 | xicotencatl
# Processing Record 30 of Set 4 | itarema
# Processing Record 31 of Set 4 | praia
# Processing Record 32 of Set 4 | sola
# Processing Record 33 of Set 4 | kokopo
# Processing Record 34 of Set 4 | yeppoon
# Processing Record 35 of Set 4 | kodiak
# Processing Record 36 of Set 4 | narsaq
# Processing Record 37 of Set 4 | chokurdakh
# Processing Record 38 of Set 4 | tilichiki
# Processing Record 39 of Set 4 | enumclaw
# Processing Record 40 of Set 4 | brindisi
# Processing Record 41 of Set 4 | severo-kurilsk
# Processing Record 42 of Set 4 | atherton
# Processing Record 43 of Set 4 | touros
# Processing Record 44 of Set 4 | provideniya
# Processing Record 45 of Set 4 | araouane
# Processing Record 46 of Set 4 | la romana
# Processing Record 47 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 4 | hirapur
# Processing Record 49 of Set 4 | liapades
# City not found. Skipping...
# Processing Record 50 of Set 4 | tromso
# Processing Record 1 of Set 5 | fortuna
# Processing Record 2 of Set 5 | vila franca do campo
# Processing Record 3 of Set 5 | okakarara
# Processing Record 4 of Set 5 | kirakira
# Processing Record 5 of Set 5 | atar
# Processing Record 6 of Set 5 | badvel
# Processing Record 7 of Set 5 | umba
# Processing Record 8 of Set 5 | conceicao do araguaia
# Processing Record 9 of Set 5 | montepuez
# Processing Record 10 of Set 5 | khandyga
# Processing Record 11 of Set 5 | tanout
# Processing Record 12 of Set 5 | biak
# Processing Record 13 of Set 5 | santa maria
# Processing Record 14 of Set 5 | lemon tree passage
# Processing Record 15 of Set 5 | huilong
# Processing Record 16 of Set 5 | longyearbyen
# Processing Record 17 of Set 5 | saskylakh
# Processing Record 18 of Set 5 | boda
# Processing Record 19 of Set 5 | hithadhoo
# Processing Record 20 of Set 5 | maiduguri
# Processing Record 21 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 22 of Set 5 | buraydah
# Processing Record 23 of Set 5 | kolondieba
# Processing Record 24 of Set 5 | gambela
# Processing Record 25 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 5 | shelburne
# Processing Record 27 of Set 5 | thompson
# Processing Record 28 of Set 5 | soe
# Processing Record 29 of Set 5 | sur
# Processing Record 30 of Set 5 | high level
# Processing Record 31 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 5 | sovetskiy
# Processing Record 33 of Set 5 | kazachinskoye
# Processing Record 34 of Set 5 | lorengau
# Processing Record 35 of Set 5 | prijepolje
# Processing Record 36 of Set 5 | acapulco
# Processing Record 37 of Set 5 | chuy
# Processing Record 38 of Set 5 | akyab
# Processing Record 39 of Set 5 | ancud
# Processing Record 40 of Set 5 | topchikha
# Processing Record 41 of Set 5 | cockburn town
# Processing Record 42 of Set 5 | porto empedocle
# Processing Record 43 of Set 5 | grindavik
# Processing Record 44 of Set 5 | butaritari
# Processing Record 45 of Set 5 | norman wells
# Processing Record 46 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 5 | bengkulu
# Processing Record 48 of Set 5 | iquique
# Processing Record 49 of Set 5 | kenai
# Processing Record 50 of Set 5 | suntar
# Processing Record 1 of Set 6 | kruisfontein
# Processing Record 2 of Set 6 | alizai
# Processing Record 3 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 4 of Set 6 | ilulissat
# Processing Record 5 of Set 6 | mahebourg
# Processing Record 6 of Set 6 | vangaindrano
# Processing Record 7 of Set 6 | morehead
# Processing Record 8 of Set 6 | hargeysa
# Processing Record 9 of Set 6 | port elizabeth
# Processing Record 10 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 6 | kalino
# Processing Record 12 of Set 6 | torbay
# Processing Record 13 of Set 6 | killybegs
# Processing Record 14 of Set 6 | hobyo
# Processing Record 15 of Set 6 | mogadishu
# Processing Record 16 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 6 | tual
# Processing Record 18 of Set 6 | vanimo
# Processing Record 19 of Set 6 | portland
# Processing Record 20 of Set 6 | kisangani
# Processing Record 21 of Set 6 | nelson bay
# Processing Record 22 of Set 6 | zambezi
# Processing Record 23 of Set 6 | hovd
# Processing Record 24 of Set 6 | ierapetra
# Processing Record 25 of Set 6 | plettenberg bay
# Processing Record 26 of Set 6 | dongsheng
# Processing Record 27 of Set 6 | brigantine
# Processing Record 28 of Set 6 | kaoma
# Processing Record 29 of Set 6 | mali
# Processing Record 30 of Set 6 | robertsport
# Processing Record 31 of Set 6 | nishihara
# Processing Record 32 of Set 6 | umm kaddadah
# Processing Record 33 of Set 6 | eyl
# Processing Record 34 of Set 6 | vallenar
# Processing Record 35 of Set 6 | bethel
# Processing Record 36 of Set 6 | svetlaya
# Processing Record 37 of Set 6 | jilib
# Processing Record 38 of Set 6 | berbera
# Processing Record 39 of Set 6 | harbour breton
# Processing Record 40 of Set 6 | tupanatinga
# Processing Record 41 of Set 6 | dikson
# Processing Record 42 of Set 6 | xai-xai
# Processing Record 43 of Set 6 | vila velha
# Processing Record 44 of Set 6 | mazagao
# Processing Record 45 of Set 6 | morondava
# Processing Record 46 of Set 6 | panama city
# Processing Record 47 of Set 6 | gat
# Processing Record 48 of Set 6 | gurupi
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | ugoofaaru
# Processing Record 1 of Set 7 | gamba
# Processing Record 2 of Set 7 | anadyr
# Processing Record 3 of Set 7 | barcelos
# Processing Record 4 of Set 7 | haapsalu
# Processing Record 5 of Set 7 | menzelinsk
# Processing Record 6 of Set 7 | galesong
# Processing Record 7 of Set 7 | campo grande
# Processing Record 8 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 7 | kemin
# Processing Record 10 of Set 7 | ocampo
# Processing Record 11 of Set 7 | hailar
# Processing Record 12 of Set 7 | san rafael
# Processing Record 13 of Set 7 | salalah
# Processing Record 14 of Set 7 | cidreira
# Processing Record 15 of Set 7 | emporia
# Processing Record 16 of Set 7 | nantucket
# Processing Record 17 of Set 7 | coquimbo
# Processing Record 18 of Set 7 | asau
# Processing Record 19 of Set 7 | meinung
# City not found. Skipping...
# Processing Record 20 of Set 7 | saint-philippe
# Processing Record 21 of Set 7 | nouadhibou
# Processing Record 22 of Set 7 | arraial do cabo
# Processing Record 23 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 24 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 7 | san jose
# Processing Record 26 of Set 7 | cabo san lucas
# Processing Record 27 of Set 7 | ashoknagar
# Processing Record 28 of Set 7 | mao
# Processing Record 29 of Set 7 | ajra
# Processing Record 30 of Set 7 | mattawa
# Processing Record 31 of Set 7 | kununurra
# Processing Record 32 of Set 7 | kavaratti
# Processing Record 33 of Set 7 | marzuq
# Processing Record 34 of Set 7 | kindu
# Processing Record 35 of Set 7 | tarboro
# Processing Record 36 of Set 7 | moerai
# Processing Record 37 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 38 of Set 7 | boca do acre
# Processing Record 39 of Set 7 | la union
# Processing Record 40 of Set 7 | omsukchan
# Processing Record 41 of Set 7 | sept-iles
# Processing Record 42 of Set 7 | paralimni
# Processing Record 43 of Set 7 | pontianak
# Processing Record 44 of Set 7 | lavrentiya
# Processing Record 45 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 46 of Set 7 | karratha
# Processing Record 47 of Set 7 | udachnyy
# Processing Record 48 of Set 7 | tirat karmel
# Processing Record 49 of Set 7 | srednekolymsk
# Processing Record 50 of Set 7 | te anau
# Processing Record 1 of Set 8 | iqaluit
# Processing Record 2 of Set 8 | kaitangata
# Processing Record 3 of Set 8 | muroto
# Processing Record 4 of Set 8 | lagoa
# Processing Record 5 of Set 8 | dakar
# Processing Record 6 of Set 8 | puerto narino
# Processing Record 7 of Set 8 | flinders
# Processing Record 8 of Set 8 | cabra
# Processing Record 9 of Set 8 | sindor
# Processing Record 10 of Set 8 | holme
# Processing Record 11 of Set 8 | ternate
# Processing Record 12 of Set 8 | sistranda
# Processing Record 13 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 8 | bima
# Processing Record 15 of Set 8 | duxbury
# Processing Record 16 of Set 8 | najran
# Processing Record 17 of Set 8 | montijo
# Processing Record 18 of Set 8 | santa cruz cabralia
# Processing Record 19 of Set 8 | cayenne
# Processing Record 20 of Set 8 | walvis bay
# Processing Record 21 of Set 8 | nova esperanca
# Processing Record 22 of Set 8 | port blair
# Processing Record 23 of Set 8 | honiara
# Processing Record 24 of Set 8 | mokobeng
# Processing Record 25 of Set 8 | isangel
# Processing Record 26 of Set 8 | spring valley
# Processing Record 27 of Set 8 | prince rupert
# Processing Record 28 of Set 8 | jertih
# Processing Record 29 of Set 8 | mackay
# Processing Record 30 of Set 8 | nanortalik
# Processing Record 31 of Set 8 | south yuba city
# Processing Record 32 of Set 8 | lompoc
# Processing Record 33 of Set 8 | santo augusto
# Processing Record 34 of Set 8 | sao borja
# Processing Record 35 of Set 8 | sao jose da coroa grande
# Processing Record 36 of Set 8 | bajo baudo
# City not found. Skipping...
# Processing Record 37 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 38 of Set 8 | chunskiy
# Processing Record 39 of Set 8 | neiafu
# Processing Record 40 of Set 8 | tuy hoa
# Processing Record 41 of Set 8 | constitucion
# Processing Record 42 of Set 8 | cortez
# Processing Record 43 of Set 8 | yumen
# Processing Record 44 of Set 8 | westport
# Processing Record 45 of Set 8 | bognor regis
# Processing Record 46 of Set 8 | bonthe
# Processing Record 47 of Set 8 | floresta
# Processing Record 48 of Set 8 | myitkyina
# Processing Record 49 of Set 8 | bathsheba
# Processing Record 50 of Set 8 | novobirilyussy
# Processing Record 1 of Set 9 | siguiri
# Processing Record 2 of Set 9 | beloha
# Processing Record 3 of Set 9 | sita road
# Processing Record 4 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 9 | smithers
# Processing Record 6 of Set 9 | ganzhou
# Processing Record 7 of Set 9 | omagh
# Processing Record 8 of Set 9 | winneba
# Processing Record 9 of Set 9 | namibe
# Processing Record 10 of Set 9 | vao
# Processing Record 11 of Set 9 | acarau
# Processing Record 12 of Set 9 | sambava
# Processing Record 13 of Set 9 | komsomolskiy
# Processing Record 14 of Set 9 | port hardy
# Processing Record 15 of Set 9 | port hawkesbury
# Processing Record 16 of Set 9 | suleya
# Processing Record 17 of Set 9 | villa bruzual
# Processing Record 18 of Set 9 | davila
# Processing Record 19 of Set 9 | urumqi
# Processing Record 20 of Set 9 | payo
# Processing Record 21 of Set 9 | kasempa
# Processing Record 22 of Set 9 | pottstown
# Processing Record 23 of Set 9 | san patricio
# Processing Record 24 of Set 9 | swan hill
# Processing Record 25 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 9 | udarnyy
# Processing Record 27 of Set 9 | srandakan
# Processing Record 28 of Set 9 | sitka
# Processing Record 29 of Set 9 | muyezerskiy
# Processing Record 30 of Set 9 | lander
# Processing Record 31 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 32 of Set 9 | pervomayskoye
# Processing Record 33 of Set 9 | ajaccio
# Processing Record 34 of Set 9 | alice springs
# Processing Record 35 of Set 9 | willmar
# Processing Record 36 of Set 9 | westpunt
# City not found. Skipping...
# Processing Record 37 of Set 9 | bereda
# Processing Record 38 of Set 9 | kurilsk
# Processing Record 39 of Set 9 | pinawa
# Processing Record 40 of Set 9 | thinadhoo
# Processing Record 41 of Set 9 | karaton
# Processing Record 42 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 9 | saint-pierre
# Processing Record 44 of Set 9 | airai
# Processing Record 45 of Set 9 | kaka
# Processing Record 46 of Set 9 | litovko
# Processing Record 47 of Set 9 | aklavik
# Processing Record 48 of Set 9 | hamilton
# Processing Record 49 of Set 9 | pochutla
# Processing Record 50 of Set 9 | avera
# Processing Record 1 of Set 10 | skaudvile
# Processing Record 2 of Set 10 | campbellsville
# Processing Record 3 of Set 10 | mahajanga
# Processing Record 4 of Set 10 | gazli
# Processing Record 5 of Set 10 | saint-francois
# Processing Record 6 of Set 10 | chernyshevskiy
# Processing Record 7 of Set 10 | rio de janeiro
# Processing Record 8 of Set 10 | dhidhdhoo
# Processing Record 9 of Set 10 | usinsk
# Processing Record 10 of Set 10 | margate
# Processing Record 11 of Set 10 | khash
# Processing Record 12 of Set 10 | moree
# Processing Record 13 of Set 10 | sena madureira
# Processing Record 14 of Set 10 | hasaki
# Processing Record 15 of Set 10 | coruripe
# Processing Record 16 of Set 10 | makakilo city
# Processing Record 17 of Set 10 | jinka
# Processing Record 18 of Set 10 | toyooka
# Processing Record 19 of Set 10 | okha
# Processing Record 20 of Set 10 | koumac
# Processing Record 21 of Set 10 | teguise
# Processing Record 22 of Set 10 | panaba
# Processing Record 23 of Set 10 | hami
# Processing Record 24 of Set 10 | lakes entrance
# Processing Record 25 of Set 10 | kavieng
# Processing Record 26 of Set 10 | viedma
# Processing Record 27 of Set 10 | point pleasant
# Processing Record 28 of Set 10 | merritt island
# Processing Record 29 of Set 10 | amboasary
# Processing Record 30 of Set 10 | ericeira
# Processing Record 31 of Set 10 | salamiyah
# Processing Record 32 of Set 10 | dwarka
# Processing Record 33 of Set 10 | harper
# Processing Record 34 of Set 10 | abha
# Processing Record 35 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 36 of Set 10 | port said
# Processing Record 37 of Set 10 | tessalit
# Processing Record 38 of Set 10 | san andres
# Processing Record 39 of Set 10 | quatre cocos
# Processing Record 40 of Set 10 | grand gaube
# Processing Record 41 of Set 10 | zhaotong
# Processing Record 42 of Set 10 | comodoro rivadavia
# Processing Record 43 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 44 of Set 10 | bahia de caraquez
# Processing Record 45 of Set 10 | kulhudhuffushi
# Processing Record 46 of Set 10 | biltine
# Processing Record 47 of Set 10 | yilan
# Processing Record 48 of Set 10 | pachino
# Processing Record 49 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 50 of Set 10 | manali
# Processing Record 1 of Set 11 | dingle
# Processing Record 2 of Set 11 | goderich
# Processing Record 3 of Set 11 | camapua
# Processing Record 4 of Set 11 | svobodnyy
# Processing Record 5 of Set 11 | kurchum
# Processing Record 6 of Set 11 | nome
# Processing Record 7 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 8 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 9 of Set 11 | ati
# Processing Record 10 of Set 11 | arlit
# Processing Record 11 of Set 11 | laguna
# Processing Record 12 of Set 11 | ambulu
# Processing Record 13 of Set 11 | iwo
# Processing Record 14 of Set 11 | talcahuano
# Processing Record 15 of Set 11 | zenica
# Processing Record 16 of Set 11 | kortkeros
# Processing Record 17 of Set 11 | korla
# Processing Record 18 of Set 11 | yinchuan
# Processing Record 19 of Set 11 | ostrovnoy
# Processing Record 20 of Set 11 | tigil
# Processing Record 21 of Set 11 | yichang
# Processing Record 22 of Set 11 | havelock
# Processing Record 23 of Set 11 | salina
# Processing Record 24 of Set 11 | shizunai
# Processing Record 25 of Set 11 | hauterive
# Processing Record 26 of Set 11 | havre
# Processing Record 27 of Set 11 | vigrestad
# Processing Record 28 of Set 11 | itanhaem
# Processing Record 29 of Set 11 | saint george
# Processing Record 30 of Set 11 | champerico
# Processing Record 31 of Set 11 | los llanos de aridane
# Processing Record 32 of Set 11 | college
# Processing Record 33 of Set 11 | astoria
# Processing Record 34 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 11 | vardo
# Processing Record 36 of Set 11 | oranjemund
# Processing Record 37 of Set 11 | oyem
# Processing Record 38 of Set 11 | aykhal
# Processing Record 39 of Set 11 | cuauhtemoc
# Processing Record 40 of Set 11 | palana
# Processing Record 41 of Set 11 | asaba
# Processing Record 42 of Set 11 | waipawa
# Processing Record 43 of Set 11 | santa isabel do rio negro
# Processing Record 44 of Set 11 | bjelovar
# Processing Record 45 of Set 11 | dien bien
# City not found. Skipping...
# Processing Record 46 of Set 11 | fort payne
# Processing Record 47 of Set 11 | mizan teferi
# Processing Record 48 of Set 11 | benghazi
# Processing Record 49 of Set 11 | anito
# Processing Record 50 of Set 11 | dharmapuri
# Processing Record 1 of Set 12 | oxford
# Processing Record 2 of Set 12 | cristalina
# Processing Record 3 of Set 12 | buta
# Processing Record 4 of Set 12 | talnakh
# Processing Record 5 of Set 12 | maloy
# Processing Record 6 of Set 12 | benito juarez
# Processing Record 7 of Set 12 | bereslavka
# Processing Record 8 of Set 12 | tuatapere
# Processing Record 9 of Set 12 | biskamzha
# Processing Record 10 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 12 | sabha
# Processing Record 12 of Set 12 | aosta
# Processing Record 13 of Set 12 | ruteng
# Processing Record 14 of Set 12 | lazaro cardenas
# Processing Record 15 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 12 | puri
# Processing Record 17 of Set 12 | serenje
# Processing Record 18 of Set 12 | milkovo
# Processing Record 19 of Set 12 | mashhad
# Processing Record 20 of Set 12 | viraganur
# Processing Record 21 of Set 12 | la ronge
# Processing Record 22 of Set 12 | kavaje
# Processing Record 23 of Set 12 | trinidad
# Processing Record 24 of Set 12 | sinnamary
# Processing Record 25 of Set 12 | tall kayf
# Processing Record 26 of Set 12 | guamuchil
# Processing Record 27 of Set 12 | lata
# Processing Record 28 of Set 12 | shenjiamen
# Processing Record 29 of Set 12 | mana
# Processing Record 30 of Set 12 | olafsvik
# Processing Record 31 of Set 12 | ixtapa
# Processing Record 32 of Set 12 | surab
# Processing Record 33 of Set 12 | togur
# Processing Record 34 of Set 12 | saint anthony
# Processing Record 35 of Set 12 | kudinovo
# Processing Record 36 of Set 12 | igarka
# Processing Record 37 of Set 12 | gari
# Processing Record 38 of Set 12 | lasa
# Processing Record 39 of Set 12 | orlik
# Processing Record 40 of Set 12 | orhei
# Processing Record 41 of Set 12 | novyy urgal
# Processing Record 42 of Set 12 | den helder
# Processing Record 43 of Set 12 | shiraz
# Processing Record 44 of Set 12 | ojinaga
# Processing Record 45 of Set 12 | faya
# Processing Record 46 of Set 12 | sinazongwe
# Processing Record 47 of Set 12 | hazorasp
# Processing Record 48 of Set 12 | inirida
# Processing Record 49 of Set 12 | wisconsin rapids
# Processing Record 50 of Set 12 | omutninsk
# Processing Record 1 of Set 13 | atbasar
# Processing Record 2 of Set 13 | ballitoville
# Processing Record 3 of Set 13 | sompeta
# Processing Record 4 of Set 13 | ketchikan
# Processing Record 5 of Set 13 | indramayu
# Processing Record 6 of Set 13 | ayr
# Processing Record 7 of Set 13 | brownsville
# Processing Record 8 of Set 13 | kombai
# Processing Record 9 of Set 13 | a
# City not found. Skipping...
# Processing Record 10 of Set 13 | ngunguru
# Processing Record 11 of Set 13 | tambura
# Processing Record 12 of Set 13 | norden
# Processing Record 13 of Set 13 | altamira
# Processing Record 14 of Set 13 | husavik
# Processing Record 15 of Set 13 | salinopolis
# Processing Record 16 of Set 13 | kahului
# Processing Record 17 of Set 13 | harenkarspel
# Processing Record 18 of Set 13 | catuday
# Processing Record 19 of Set 13 | santa lucia
# Processing Record 20 of Set 13 | copiapo
# Processing Record 21 of Set 13 | siocon
# Processing Record 22 of Set 13 | nakhon phanom
# Processing Record 23 of Set 13 | at-bashi
# Processing Record 24 of Set 13 | tecolutla
# Processing Record 25 of Set 13 | nurota
# Processing Record 26 of Set 13 | zavoaia
# Processing Record 27 of Set 13 | kamaishi
# Processing Record 28 of Set 13 | hualmay
# Processing Record 29 of Set 13 | brewster
# Processing Record 30 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 31 of Set 13 | mangochi
# Processing Record 32 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 13 | bubaque
# Processing Record 34 of Set 13 | victor harbor
# Processing Record 35 of Set 13 | nizhniy kuranakh
# Processing Record 36 of Set 13 | sorong
# Processing Record 37 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 13 | mastic beach
# Processing Record 40 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 13 | cangzhou
# Processing Record 42 of Set 13 | homer
# Processing Record 43 of Set 13 | ileza
# Processing Record 44 of Set 13 | jonesboro
# Processing Record 45 of Set 13 | porto santo
# Processing Record 46 of Set 13 | marawi
# Processing Record 47 of Set 13 | sedro-woolley
# Processing Record 48 of Set 13 | lardos
# Processing Record 49 of Set 13 | zlatoustovsk
# City not found. Skipping...
# Processing Record 50 of Set 13 | nemuro
# Processing Record 1 of Set 14 | williston
# Processing Record 2 of Set 14 | yanchukan
# City not found. Skipping...
# Processing Record 3 of Set 14 | djang
# City not found. Skipping...
# Processing Record 4 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 5 of Set 14 | sekoma
# Processing Record 6 of Set 14 | veraval
# Processing Record 7 of Set 14 | springbok
# Processing Record 8 of Set 14 | tandil
# Processing Record 9 of Set 14 | cururupu
# Processing Record 10 of Set 14 | jega
# Processing Record 11 of Set 14 | angoche
# Processing Record 12 of Set 14 | ossora
# Processing Record 13 of Set 14 | victoria
# Processing Record 14 of Set 14 | aksarka
# Processing Record 15 of Set 14 | aswan
# Processing Record 16 of Set 14 | bandarbeyla
# Processing Record 17 of Set 14 | guarapari
# Processing Record 18 of Set 14 | trairi
# Processing Record 19 of Set 14 | vaitape
# Processing Record 20 of Set 14 | tutoia
# Processing Record 21 of Set 14 | khandbari
# Processing Record 22 of Set 14 | batagay-alyta
# Processing Record 23 of Set 14 | cocobeach
# Processing Record 24 of Set 14 | joshimath
# Processing Record 25 of Set 14 | pizarro
# Processing Record 26 of Set 14 | rawson
# Processing Record 27 of Set 14 | karpathos
# Processing Record 28 of Set 14 | richards bay
# Processing Record 29 of Set 14 | paternion
# Processing Record 30 of Set 14 | jizan
# Processing Record 31 of Set 14 | belyy yar
# Processing Record 32 of Set 14 | uk
# City not found. Skipping...
# Processing Record 33 of Set 14 | corinto
# Processing Record 34 of Set 14 | urfa
# City not found. Skipping...
# Processing Record 35 of Set 14 | taltal
# Processing Record 36 of Set 14 | saquena
# Processing Record 37 of Set 14 | vuktyl
# Processing Record 38 of Set 14 | zirovnice
# Processing Record 39 of Set 14 | astana
# Processing Record 40 of Set 14 | torres
# Processing Record 41 of Set 14 | nisia floresta
# Processing Record 42 of Set 14 | san isidro
# Processing Record 43 of Set 14 | marinette
# Processing Record 44 of Set 14 | horsham
# Processing Record 45 of Set 14 | gopalpur
# Processing Record 46 of Set 14 | pundaguitan
# Processing Record 47 of Set 14 | pascagoula
# Processing Record 48 of Set 14 | katherine
# Processing Record 49 of Set 14 | labuhan
# Processing Record 50 of Set 14 | graaff-reinet
# Processing Record 1 of Set 15 | bokoro
# Processing Record 2 of Set 15 | chabahar
# Processing Record 3 of Set 15 | mwingi
# Processing Record 4 of Set 15 | waingapu
# Processing Record 5 of Set 15 | bulgan
# Processing Record 6 of Set 15 | ustrzyki dolne
# Processing Record 7 of Set 15 | yulara
# Processing Record 8 of Set 15 | birjand
# Processing Record 9 of Set 15 | vostok
# Processing Record 10 of Set 15 | katobu
# Processing Record 11 of Set 15 | las vegas
# Processing Record 12 of Set 15 | mantua
# Processing Record 13 of Set 15 | tura
# Processing Record 14 of Set 15 | safranbolu
# Processing Record 15 of Set 15 | vicuna
# Processing Record 16 of Set 15 | blairmore
# Processing Record 17 of Set 15 | batemans bay
# Processing Record 18 of Set 15 | lake cowichan
# Processing Record 19 of Set 15 | herat
# Processing Record 20 of Set 15 | port hedland
# Processing Record 21 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 15 | guymon
# Processing Record 23 of Set 15 | gizo
# Processing Record 24 of Set 15 | imbituba
# Processing Record 25 of Set 15 | zyryanka
# Processing Record 26 of Set 15 | umm lajj
# Processing Record 27 of Set 15 | caborca
# Processing Record 28 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 29 of Set 15 | sarkand
# Processing Record 30 of Set 15 | zhangye
# Processing Record 31 of Set 15 | peoria
# Processing Record 32 of Set 15 | puerto ayacucho
# Processing Record 33 of Set 15 | kyshtovka
# Processing Record 34 of Set 15 | aasiaat
# Processing Record 35 of Set 15 | oga
# Processing Record 36 of Set 15 | ewa beach
# Processing Record 37 of Set 15 | hervey bay
# Processing Record 38 of Set 15 | gainesville
# Processing Record 39 of Set 15 | lancaster
# Processing Record 40 of Set 15 | wilmington island
# Processing Record 41 of Set 15 | male
# Processing Record 42 of Set 15 | kristinehamn
# Processing Record 43 of Set 15 | beringovskiy
# Processing Record 44 of Set 15 | christchurch
# Processing Record 45 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 46 of Set 15 | yayva
# Processing Record 47 of Set 15 | yining
# Processing Record 48 of Set 15 | taitung
# Processing Record 49 of Set 15 | krasnoselkup
# Processing Record 50 of Set 15 | auki
# Processing Record 1 of Set 16 | katsuura
# Processing Record 2 of Set 16 | muleba
# Processing Record 3 of Set 16 | karakendzha
# City not found. Skipping...
# Processing Record 4 of Set 16 | kalvarija
# Processing Record 5 of Set 16 | kristiansund
# Processing Record 6 of Set 16 | razdolinsk
# Processing Record 7 of Set 16 | dargaville
# Processing Record 8 of Set 16 | tooele
# Processing Record 9 of Set 16 | suluq
# Processing Record 10 of Set 16 | havre-saint-pierre
# Processing Record 11 of Set 16 | gladstone
# Processing Record 12 of Set 16 | gerede
# Processing Record 13 of Set 16 | patos de minas
# Processing Record 14 of Set 16 | messina
# Processing Record 15 of Set 16 | rio grande
# Processing Record 16 of Set 16 | roald
# Processing Record 17 of Set 16 | amahai
# Processing Record 18 of Set 16 | la palma
# Processing Record 19 of Set 16 | horki
# Processing Record 20 of Set 16 | cabedelo
# Processing Record 21 of Set 16 | egvekinot
# Processing Record 22 of Set 16 | bataipora
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 707

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea -23.1203 -134.9692     79.52        77           3
# 1       Nikolskoye  59.7035   30.7861     22.89        98          70
# 2           Jalpan  21.2333  -99.4833     78.46        51          20
# 3            Pisco -13.7000  -76.2167     73.02        80          52
# 4         Hermanus -34.4187   19.2345     68.81        74          82
# 5           Atuona  -9.8000 -139.0333     79.20        71          74
# 6         Qaqortoq  60.7167  -46.0333     10.90        67           0
# 7  Bambous Virieux -20.3428   57.7575     78.22        81         100
# 8       Codrington -38.2667  141.9667     63.25        85         100
# 9        Upernavik  72.7868  -56.1549    -23.98        68          65
#
#    Wind Speed Country Weather Description
# 0       16.96      PF           clear sky
# 1        3.09      RU       broken clouds
# 2        8.59      MX          few clouds
# 3        9.71      PE       broken clouds
# 4       12.46      ZA       broken clouds
# 5       20.33      PF       broken clouds
# 6        7.56      GL           clear sky
# 7        7.99      MU     overcast clouds
# 8        6.49      AU     overcast clouds
# 9        8.84      GL       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Change column name
city_data_df = city_data_df.rename(columns={"Weather Description": "Current Description"})

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_order]

# Display sample data
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Rikitea      PF -23.1203 -134.9692     79.52        77           3
# 1       Nikolskoye      RU  59.7035   30.7861     22.89        98          70
# 2           Jalpan      MX  21.2333  -99.4833     78.46        51          20
# 3            Pisco      PE -13.7000  -76.2167     73.02        80          52
# 4         Hermanus      ZA -34.4187   19.2345     68.81        74          82
# 5           Atuona      PF  -9.8000 -139.0333     79.20        71          74
# 6         Qaqortoq      GL  60.7167  -46.0333     10.90        67           0
# 7  Bambous Virieux      MU -20.3428   57.7575     78.22        81         100
# 8       Codrington      AU -38.2667  141.9667     63.25        85         100
# 9        Upernavik      GL  72.7868  -56.1549    -23.98        68          65
#
#    Wind Speed Current Description
# 0       16.96           clear sky
# 1        3.09       broken clouds
# 2        8.59          few clouds
# 3        9.71       broken clouds
# 4       12.46       broken clouds
# 5       20.33       broken clouds
# 6        7.56           clear sky
# 7        7.99     overcast clouds
# 8        6.49     overcast clouds
# 9        8.84       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "./WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
